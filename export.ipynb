# %%
# !tar chvfz project.tar.gz *
# Out:
# algos/
# algos/agent_base.py
# algos/ddpg_agent.py
# algos/ddpg_extension.py
# algos/ddpg_utils.py
# algos/ppo_agent.py
# algos/ppo_extension.py
# algos/ppo_utils.py
# algos/.ipynb_checkpoints/
# algos/.ipynb_checkpoints/agent_base-checkpoint.py
# algos/.ipynb_checkpoints/ddpg_agent-checkpoint.py
# algos/.ipynb_checkpoints/ddpg_extension-checkpoint.py
# algos/.ipynb_checkpoints/ddpg_utils-checkpoint.py
# algos/.ipynb_checkpoints/ppo_agent-checkpoint.py
# algos/.ipynb_checkpoints/ppo_extension-checkpoint.py
# algos/.ipynb_checkpoints/ppo_utils-checkpoint.py
# algos/__pycache__/
# algos/__pycache__/ppo_agent.cpython-310.pyc
# algos/__pycache__/agent_base.cpython-310.pyc
# algos/__pycache__/ppo_utils.cpython-310.pyc
# algos/__pycache__/ddpg_extension.cpython-310.pyc
# algos/__pycache__/ddpg_utils.cpython-310.pyc
# algos/__pycache__/ppo_extension.cpython-310.pyc
# cfg/
# cfg/algo/
# cfg/algo/ddpg.yaml
# cfg/algo/ddpg_extension.yaml
# cfg/algo/ppo.yaml
# cfg/algo/ppo_extension.yaml
# ...
